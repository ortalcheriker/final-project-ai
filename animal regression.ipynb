# %%
import pandas as pd
animals=pd.read_csv('/Users/ortal/Desktop/OneDrive - Ariel University/שיעורים/AI/proiect/dataset/aac_shelter_outcomes.csv')
parse_dates=['date_of_birth', 'datetime']
animals
# Out:
#       age_upon_outcome animal_id animal_type  \
# 0              2 weeks   A684346         Cat
# 1               1 year   A666430         Dog
# 2               1 year   A675708         Dog
# 3              9 years   A680386         Dog
# 4             5 months   A683115       Other
# ...                ...       ...         ...
# 78251          1 month   A764894         Dog
# 78252          3 years   A764468         Dog
# 78253              NaN   A766098       Other
# 78254         2 months   A765858         Dog
# 78255         2 months   A765857         Dog
#
#                                      breed         color        date_of_birth  \
# 0                   Domestic Shorthair Mix  Orange Tabby  2014-07-07T00:00:00
# 1                               Beagle Mix   White/Brown  2012-11-06T00:00:00
# 2                                 Pit Bull    Blue/White  2013-03-31T00:00:00
# 3                  Miniature Schnauzer Mix         White  2005-06-02T00:00:00
# ...

# %% [markdown]
# כמה יצאו לאימוץ?
# כמה הועברו למקום אחר?
# קורולציה-צבע ואימוץ/גזע ואימוץ/גיל ואימוץ/מין ואימוץ?
# כמה בעלי חיים יש מכל סוג?
#
# השאלה הגדולה-מה משפיע על אימוץ של בעל חיים?

# %%
##animals['outcome_type'].unique()
# Out:
# array(['Transfer', 'Adoption', 'Euthanasia', 'Return to Owner', 'Died',
#        'Disposal', 'Relocate', 'Missing', nan, 'Rto-Adopt'], dtype=object)

# %% [markdown]
# # Explanation of the relevant features:\
# **Animals type**- there is 4 types:
# * dogs
# * cats
# * livestock-Farm animals like pig, sheep and goat
# * other-Wild animals - for example turtle, deer, bat and hyena
#
# **breed**-the brid of the animale\
# **color**-the color of the animal\
# **date of birth**-The estimated date on which the animal was born\
# **date time**-The date the animal left the shelter
# **outcome_type**-the reason why the animal left the shelter. there is 9 reasons:
# * Transfer-The animal was transferred to a shelter or farm elsewhere
# * Adoption
# * Euthanasia-The animal was killed for humane reasons
# * Return to Owner
# * Died
# * Disposal-The animal was removed from the shelter
# * Relocate
# * Missing-The animal went missing from the shelter for unknown reasons and has not been located
# * Rto-Adopt-the animal was returned to its owner through the shelter's adoption process.
#
#
# **sex_upon_outcome**-there is  kind of sex:
# * Intact Female
# * Intact male
# * Neutered Male
# * Spayed Female
# * unknown

# %% [markdown]
# fetures that I erease and the reason:
# **animal id**-The feature allows for easier identification of the animal, but is not relevant to the project
# **monthyear**- this date is the same as datetime.
# **name**- The name of the animal has no effect on its adoption as it is something that can be changed
# **outcome subtype**-The sub-reason why the animal left the shelter. This is irrelevant because they are included under more comprehensive reasons, on which the model will work.
# this parameters not make any change on the target.

# %% [markdown]
# # todo:
# delete the unnessary featurs.
# delete raws with null in the outcomtype
# plots:
# anymals type\color\age
# (**pay attantion to do new column with the calculate of the  birth year and the datetime to know how old the animalse is??**)
